# %% [markdown]
# # Com DuckDB

# %%
PARQUET_FILE_NAME = "receita.parquet"

# %%
import duckdb

df = duckdb.sql(
    f"""
    SELECT
        *
    FROM read_parquet(
        '../data/02-bronze/{PARQUET_FILE_NAME}'
    )
    LIMIT 20
    """
).df()

df.head()
# Out:
#   dt_geracao hh_geracao cd_tp_esfera_partidaria ds_tp_espera_partidaria sg_uf  \
# 0 2026-04-25   16:24:44                       0                NACIONAL    BR
# 1 2026-04-25   16:24:44                       0                NACIONAL    BR
# 2 2026-04-25   16:24:44                       0                NACIONAL    BR
# 3 2026-04-25   16:24:44                       0                NACIONAL    BR
# 4 2026-04-25   16:24:44                       0                NACIONAL    BR
#
#   cd_municipio nm_municipio  nr_zona cd_cnpj_prestador_conta sg_partido  ...  \
# 0         None         None      NaN          32206989000180       AGIR  ...
# 1         None         None      NaN          32206989000180       AGIR  ...
# 2         None         None      NaN          32206989000180       AGIR  ...
# 3         None         None      NaN          32206989000180       AGIR  ...
# 4         None         None      NaN          32206989000180       AGIR  ...
#
# ...
